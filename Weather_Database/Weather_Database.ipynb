# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 720

# %%
# Import the requests library.
import requests

# Import the API key.
from config2 import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | norman wells
# Processing Record 2 of Set 1 | coahuayana
# Processing Record 3 of Set 1 | isangel
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | belyy yar
# Processing Record 10 of Set 1 | tuktoyaktuk
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | thompson
# Processing Record 14 of Set 1 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | meulaboh
# Processing Record 17 of Set 1 | constitucion
# Processing Record 18 of Set 1 | iqaluit
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | klaksvik
# Processing Record 22 of Set 1 | severo-kurilsk
# Processing Record 23 of Set 1 | dikson
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | virovitica
# Processing Record 26 of Set 1 | georgetown
# Processing Record 27 of Set 1 | peno
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | mundo nuevo
# Processing Record 30 of Set 1 | luderitz
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | sterling
# Processing Record 33 of Set 1 | togul
# Processing Record 34 of Set 1 | codrington
# Processing Record 35 of Set 1 | ca mau
# Processing Record 36 of Set 1 | laguna
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | hanna
# Processing Record 40 of Set 1 | bambous virieux
# Processing Record 41 of Set 1 | bac lieu
# Processing Record 42 of Set 1 | longyearbyen
# Processing Record 43 of Set 1 | port lincoln
# Processing Record 44 of Set 1 | souillac
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | gulshat
# City not found. Skipping...
# Processing Record 47 of Set 1 | avarua
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | khatanga
# Processing Record 50 of Set 1 | bograd
# Processing Record 1 of Set 2 | morondava
# Processing Record 2 of Set 2 | gat
# Processing Record 3 of Set 2 | ribeira grande
# Processing Record 4 of Set 2 | cherskiy
# Processing Record 5 of Set 2 | puerto penasco
# Processing Record 6 of Set 2 | kanigoro
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | east london
# Processing Record 9 of Set 2 | bathsheba
# Processing Record 10 of Set 2 | carutapera
# Processing Record 11 of Set 2 | vanavara
# Processing Record 12 of Set 2 | esperance
# Processing Record 13 of Set 2 | harqalah
# Processing Record 14 of Set 2 | hilo
# Processing Record 15 of Set 2 | chokurdakh
# Processing Record 16 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 2 | port elizabeth
# Processing Record 18 of Set 2 | port arthur
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | victoria
# Processing Record 21 of Set 2 | geraldton
# Processing Record 22 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 2 | lavrentiya
# Processing Record 24 of Set 2 | vestmannaeyjar
# Processing Record 25 of Set 2 | sao joao da barra
# Processing Record 26 of Set 2 | ilulissat
# Processing Record 27 of Set 2 | lasa
# Processing Record 28 of Set 2 | atuona
# Processing Record 29 of Set 2 | nelson bay
# Processing Record 30 of Set 2 | hamilton
# Processing Record 31 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 2 | linxia
# Processing Record 33 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 2 | kaitangata
# Processing Record 35 of Set 2 | gaoua
# Processing Record 36 of Set 2 | mahebourg
# Processing Record 37 of Set 2 | de-kastri
# Processing Record 38 of Set 2 | scottsbluff
# Processing Record 39 of Set 2 | aklavik
# Processing Record 40 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 41 of Set 2 | kailua
# Processing Record 42 of Set 2 | moron
# Processing Record 43 of Set 2 | ust-barguzin
# Processing Record 44 of Set 2 | forbes
# Processing Record 45 of Set 2 | wanning
# Processing Record 46 of Set 2 | coquimbo
# Processing Record 47 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 2 | machali
# Processing Record 49 of Set 2 | tasiilaq
# Processing Record 50 of Set 2 | new norfolk
# Processing Record 1 of Set 3 | port alfred
# Processing Record 2 of Set 3 | bandarbeyla
# Processing Record 3 of Set 3 | sobolevo
# Processing Record 4 of Set 3 | ganzhou
# Processing Record 5 of Set 3 | nioro
# Processing Record 6 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 3 | fairbanks
# Processing Record 8 of Set 3 | xuanhua
# Processing Record 9 of Set 3 | hirara
# Processing Record 10 of Set 3 | kimbe
# Processing Record 11 of Set 3 | sorland
# Processing Record 12 of Set 3 | fort nelson
# Processing Record 13 of Set 3 | castro
# Processing Record 14 of Set 3 | comodoro rivadavia
# Processing Record 15 of Set 3 | sao filipe
# Processing Record 16 of Set 3 | russell
# Processing Record 17 of Set 3 | cidreira
# Processing Record 18 of Set 3 | margate
# Processing Record 19 of Set 3 | trelew
# Processing Record 20 of Set 3 | mount isa
# Processing Record 21 of Set 3 | carnarvon
# Processing Record 22 of Set 3 | wajima
# Processing Record 23 of Set 3 | usinsk
# Processing Record 24 of Set 3 | pedernales
# Processing Record 25 of Set 3 | katsuura
# Processing Record 26 of Set 3 | kudahuvadhoo
# Processing Record 27 of Set 3 | ahipara
# Processing Record 28 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 3 | talnakh
# Processing Record 30 of Set 3 | torbay
# Processing Record 31 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 3 | houston
# Processing Record 33 of Set 3 | provideniya
# Processing Record 34 of Set 3 | bethel
# Processing Record 35 of Set 3 | mangrol
# Processing Record 36 of Set 3 | olinda
# Processing Record 37 of Set 3 | shellbrook
# Processing Record 38 of Set 3 | biak
# Processing Record 39 of Set 3 | oulu
# Processing Record 40 of Set 3 | qaanaaq
# Processing Record 41 of Set 3 | tuatapere
# Processing Record 42 of Set 3 | pevek
# Processing Record 43 of Set 3 | srednekolymsk
# Processing Record 44 of Set 3 | arroyo
# Processing Record 45 of Set 3 | kavieng
# Processing Record 46 of Set 3 | college
# Processing Record 47 of Set 3 | saldanha
# Processing Record 48 of Set 3 | la roche-sur-yon
# Processing Record 49 of Set 3 | crab hill
# City not found. Skipping...
# Processing Record 50 of Set 3 | shihezi
# Processing Record 1 of Set 4 | pietrosani
# Processing Record 2 of Set 4 | mirnyy
# Processing Record 3 of Set 4 | aden
# Processing Record 4 of Set 4 | sawakin
# Processing Record 5 of Set 4 | tautira
# Processing Record 6 of Set 4 | butaritari
# Processing Record 7 of Set 4 | huarmey
# Processing Record 8 of Set 4 | turukhansk
# Processing Record 9 of Set 4 | brainerd
# Processing Record 10 of Set 4 | portland
# Processing Record 11 of Set 4 | kruisfontein
# Processing Record 12 of Set 4 | dubai
# Processing Record 13 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 4 | arraial do cabo
# Processing Record 15 of Set 4 | constantine
# Processing Record 16 of Set 4 | kavaratti
# Processing Record 17 of Set 4 | hanzhong
# Processing Record 18 of Set 4 | pisco
# Processing Record 19 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 20 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 4 | paamiut
# Processing Record 22 of Set 4 | batemans bay
# Processing Record 23 of Set 4 | alofi
# Processing Record 24 of Set 4 | mucurici
# Processing Record 25 of Set 4 | tete
# Processing Record 26 of Set 4 | sur
# Processing Record 27 of Set 4 | tucuman
# Processing Record 28 of Set 4 | husavik
# Processing Record 29 of Set 4 | okhotsk
# Processing Record 30 of Set 4 | mount gambier
# Processing Record 31 of Set 4 | dillon
# Processing Record 32 of Set 4 | san quintin
# Processing Record 33 of Set 4 | clarence town
# Processing Record 34 of Set 4 | cabo san lucas
# Processing Record 35 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 36 of Set 4 | shingu
# Processing Record 37 of Set 4 | hasaki
# Processing Record 38 of Set 4 | pemagatsel
# Processing Record 39 of Set 4 | chuy
# Processing Record 40 of Set 4 | marsa matruh
# Processing Record 41 of Set 4 | lichuan
# Processing Record 42 of Set 4 | hovd
# Processing Record 43 of Set 4 | vila franca do campo
# Processing Record 44 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 4 | burica
# City not found. Skipping...
# Processing Record 46 of Set 4 | kargopol
# Processing Record 47 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 4 | koslan
# Processing Record 50 of Set 4 | requena
# Processing Record 1 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 5 | clyde river
# Processing Record 3 of Set 5 | fort beaufort
# Processing Record 4 of Set 5 | nantucket
# Processing Record 5 of Set 5 | verkhoyansk
# Processing Record 6 of Set 5 | presidencia roque saenz pena
# Processing Record 7 of Set 5 | marrakesh
# Processing Record 8 of Set 5 | gravdal
# Processing Record 9 of Set 5 | lompoc
# Processing Record 10 of Set 5 | mar del plata
# Processing Record 11 of Set 5 | harper
# Processing Record 12 of Set 5 | shaunavon
# Processing Record 13 of Set 5 | barrow
# Processing Record 14 of Set 5 | vardo
# Processing Record 15 of Set 5 | jacobina
# Processing Record 16 of Set 5 | belmonte
# Processing Record 17 of Set 5 | buta
# Processing Record 18 of Set 5 | ajra
# Processing Record 19 of Set 5 | concordia
# Processing Record 20 of Set 5 | porbandar
# Processing Record 21 of Set 5 | kawalu
# Processing Record 22 of Set 5 | ishigaki
# Processing Record 23 of Set 5 | leningradskiy
# Processing Record 24 of Set 5 | nazare
# Processing Record 25 of Set 5 | brae
# Processing Record 26 of Set 5 | monte patria
# Processing Record 27 of Set 5 | omboue
# Processing Record 28 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 29 of Set 5 | hobyo
# Processing Record 30 of Set 5 | sovetskiy
# Processing Record 31 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 5 | kargasok
# Processing Record 33 of Set 5 | saint-pierre
# Processing Record 34 of Set 5 | kodiak
# Processing Record 35 of Set 5 | sakakah
# Processing Record 36 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 5 | tshela
# Processing Record 38 of Set 5 | diveyevo
# Processing Record 39 of Set 5 | naryan-mar
# Processing Record 40 of Set 5 | coffs harbour
# Processing Record 41 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 42 of Set 5 | boden
# Processing Record 43 of Set 5 | los llanos de aridane
# Processing Record 44 of Set 5 | ostrovnoy
# Processing Record 45 of Set 5 | santiago del estero
# Processing Record 46 of Set 5 | praya
# Processing Record 47 of Set 5 | umm lajj
# Processing Record 48 of Set 5 | san cristobal
# Processing Record 49 of Set 5 | newtownards
# Processing Record 50 of Set 5 | pacific grove
# Processing Record 1 of Set 6 | magadan
# Processing Record 2 of Set 6 | saint-joseph
# Processing Record 3 of Set 6 | talakan
# Processing Record 4 of Set 6 | port augusta
# Processing Record 5 of Set 6 | saint-philippe
# Processing Record 6 of Set 6 | nemuro
# Processing Record 7 of Set 6 | sao jose da laje
# Processing Record 8 of Set 6 | port-gentil
# Processing Record 9 of Set 6 | korla
# Processing Record 10 of Set 6 | hearst
# Processing Record 11 of Set 6 | oranjestad
# Processing Record 12 of Set 6 | ziro
# Processing Record 13 of Set 6 | san rafael
# Processing Record 14 of Set 6 | pimentel
# Processing Record 15 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 16 of Set 6 | lipin bor
# Processing Record 17 of Set 6 | kaka
# Processing Record 18 of Set 6 | hithadhoo
# Processing Record 19 of Set 6 | dingli
# Processing Record 20 of Set 6 | sainte-marie
# Processing Record 21 of Set 6 | mazara del vallo
# Processing Record 22 of Set 6 | matara
# Processing Record 23 of Set 6 | svetlogorsk
# Processing Record 24 of Set 6 | alihe
# Processing Record 25 of Set 6 | sai buri
# Processing Record 26 of Set 6 | erzin
# Processing Record 27 of Set 6 | roebourne
# Processing Record 28 of Set 6 | henties bay
# Processing Record 29 of Set 6 | hami
# Processing Record 30 of Set 6 | gigmoto
# Processing Record 31 of Set 6 | alice springs
# Processing Record 32 of Set 6 | san policarpo
# Processing Record 33 of Set 6 | chuzhou
# Processing Record 34 of Set 6 | poum
# Processing Record 35 of Set 6 | rocha
# Processing Record 36 of Set 6 | polasara
# Processing Record 37 of Set 6 | nouadhibou
# Processing Record 38 of Set 6 | srikakulam
# Processing Record 39 of Set 6 | launceston
# Processing Record 40 of Set 6 | zwettl
# Processing Record 41 of Set 6 | bingol
# Processing Record 42 of Set 6 | stephenville
# Processing Record 43 of Set 6 | lazaro cardenas
# Processing Record 44 of Set 6 | skjervoy
# Processing Record 45 of Set 6 | arinos
# Processing Record 46 of Set 6 | kurumkan
# Processing Record 47 of Set 6 | douala
# Processing Record 48 of Set 6 | matai
# Processing Record 49 of Set 6 | tianpeng
# Processing Record 50 of Set 6 | udachnyy
# Processing Record 1 of Set 7 | willowmore
# Processing Record 2 of Set 7 | rio grande
# Processing Record 3 of Set 7 | cururupu
# Processing Record 4 of Set 7 | cairns
# Processing Record 5 of Set 7 | bantry
# Processing Record 6 of Set 7 | adrar
# Processing Record 7 of Set 7 | lambarene
# Processing Record 8 of Set 7 | teya
# Processing Record 9 of Set 7 | narsaq
# Processing Record 10 of Set 7 | porto santo
# Processing Record 11 of Set 7 | nove straseci
# Processing Record 12 of Set 7 | san jeronimo
# Processing Record 13 of Set 7 | bengkulu
# Processing Record 14 of Set 7 | baruun-urt
# Processing Record 15 of Set 7 | saskylakh
# Processing Record 16 of Set 7 | port hardy
# Processing Record 17 of Set 7 | rafsanjan
# Processing Record 18 of Set 7 | mudgee
# Processing Record 19 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 21 of Set 7 | tomohon
# Processing Record 22 of Set 7 | kologriv
# Processing Record 23 of Set 7 | tiksi
# Processing Record 24 of Set 7 | methoni
# Processing Record 25 of Set 7 | bilibino
# Processing Record 26 of Set 7 | beringovskiy
# Processing Record 27 of Set 7 | pathein
# Processing Record 28 of Set 7 | upernavik
# Processing Record 29 of Set 7 | falkensee
# Processing Record 30 of Set 7 | suntar
# Processing Record 31 of Set 7 | pacifica
# Processing Record 32 of Set 7 | buraydah
# Processing Record 33 of Set 7 | axim
# Processing Record 34 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 7 | sisimiut
# Processing Record 36 of Set 7 | cumberland
# Processing Record 37 of Set 7 | salym
# Processing Record 38 of Set 7 | puerto escondido
# Processing Record 39 of Set 7 | ambilobe
# Processing Record 40 of Set 7 | vytegra
# Processing Record 41 of Set 7 | jerantut
# Processing Record 42 of Set 7 | chilca
# Processing Record 43 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 44 of Set 7 | sanand
# Processing Record 45 of Set 7 | arbuzynka
# Processing Record 46 of Set 7 | lebu
# Processing Record 47 of Set 7 | fort frances
# Processing Record 48 of Set 7 | birjand
# Processing Record 49 of Set 7 | say
# Processing Record 50 of Set 7 | great yarmouth
# Processing Record 1 of Set 8 | dunedin
# Processing Record 2 of Set 8 | hambantota
# Processing Record 3 of Set 8 | kahului
# Processing Record 4 of Set 8 | yerbogachen
# Processing Record 5 of Set 8 | boca do acre
# Processing Record 6 of Set 8 | puerto rico
# Processing Record 7 of Set 8 | saint george
# Processing Record 8 of Set 8 | maceio
# Processing Record 9 of Set 8 | arlit
# Processing Record 10 of Set 8 | soe
# Processing Record 11 of Set 8 | atasu
# Processing Record 12 of Set 8 | san patricio
# Processing Record 13 of Set 8 | kiruna
# Processing Record 14 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 15 of Set 8 | oussouye
# Processing Record 16 of Set 8 | greystones
# Processing Record 17 of Set 8 | sitka
# Processing Record 18 of Set 8 | ponta do sol
# Processing Record 19 of Set 8 | airai
# Processing Record 20 of Set 8 | immokalee
# Processing Record 21 of Set 8 | sri aman
# Processing Record 22 of Set 8 | moses lake
# Processing Record 23 of Set 8 | maple creek
# Processing Record 24 of Set 8 | vanimo
# Processing Record 25 of Set 8 | kapoeta
# Processing Record 26 of Set 8 | fare
# Processing Record 27 of Set 8 | haukipudas
# Processing Record 28 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 29 of Set 8 | poshekhonye
# Processing Record 30 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 8 | khandyga
# Processing Record 32 of Set 8 | porto novo
# Processing Record 33 of Set 8 | carndonagh
# Processing Record 34 of Set 8 | tayu
# Processing Record 35 of Set 8 | diebougou
# Processing Record 36 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 8 | eldikan
# City not found. Skipping...
# Processing Record 38 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 8 | carauari
# Processing Record 40 of Set 8 | hofn
# Processing Record 41 of Set 8 | monrovia
# Processing Record 42 of Set 8 | sehwan
# Processing Record 43 of Set 8 | bayir
# Processing Record 44 of Set 8 | inuvik
# Processing Record 45 of Set 8 | antagan
# City not found. Skipping...
# Processing Record 46 of Set 8 | pangnirtung
# Processing Record 47 of Set 8 | canutama
# Processing Record 48 of Set 8 | ketchikan
# Processing Record 49 of Set 8 | basco
# Processing Record 50 of Set 8 | calvinia
# Processing Record 1 of Set 9 | hervey bay
# Processing Record 2 of Set 9 | muika
# City not found. Skipping...
# Processing Record 3 of Set 9 | kimberley
# Processing Record 4 of Set 9 | cap malheureux
# Processing Record 5 of Set 9 | coihaique
# Processing Record 6 of Set 9 | rawson
# Processing Record 7 of Set 9 | marihatag
# Processing Record 8 of Set 9 | manosque
# Processing Record 9 of Set 9 | nouakchott
# Processing Record 10 of Set 9 | tilichiki
# Processing Record 11 of Set 9 | kajaani
# Processing Record 12 of Set 9 | sayansk
# Processing Record 13 of Set 9 | daman
# Processing Record 14 of Set 9 | ewa beach
# Processing Record 15 of Set 9 | obihiro
# Processing Record 16 of Set 9 | omsukchan
# Processing Record 17 of Set 9 | vila
# Processing Record 18 of Set 9 | aksu
# Processing Record 19 of Set 9 | kidal
# Processing Record 20 of Set 9 | presidente epitacio
# Processing Record 21 of Set 9 | bambanglipuro
# Processing Record 22 of Set 9 | manturovo
# Processing Record 23 of Set 9 | srandakan
# Processing Record 24 of Set 9 | verkhnyaya inta
# Processing Record 25 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 27 of Set 9 | san juan
# Processing Record 28 of Set 9 | raudeberg
# Processing Record 29 of Set 9 | piryion
# City not found. Skipping...
# Processing Record 30 of Set 9 | manacapuru
# Processing Record 31 of Set 9 | lagoa
# Processing Record 32 of Set 9 | bayanday
# Processing Record 33 of Set 9 | sikasso
# Processing Record 34 of Set 9 | nayoro
# Processing Record 35 of Set 9 | faanui
# Processing Record 36 of Set 9 | sonoita
# Processing Record 37 of Set 9 | envira
# Processing Record 38 of Set 9 | bubaque
# Processing Record 39 of Set 9 | higuey
# City not found. Skipping...
# Processing Record 40 of Set 9 | alta floresta
# Processing Record 41 of Set 9 | vostok
# Processing Record 42 of Set 9 | marsh harbour
# Processing Record 43 of Set 9 | belaya gora
# Processing Record 44 of Set 9 | nagorsk
# Processing Record 45 of Set 9 | angangxi
# City not found. Skipping...
# Processing Record 46 of Set 9 | singkang
# Processing Record 47 of Set 9 | maun
# Processing Record 48 of Set 9 | calvia
# Processing Record 49 of Set 9 | thunder bay
# Processing Record 50 of Set 9 | krasnyy chikoy
# Processing Record 1 of Set 10 | grindavik
# Processing Record 2 of Set 10 | caravelas
# Processing Record 3 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 4 of Set 10 | tostamaa
# City not found. Skipping...
# Processing Record 5 of Set 10 | bernay
# Processing Record 6 of Set 10 | seydisehir
# Processing Record 7 of Set 10 | north platte
# Processing Record 8 of Set 10 | havoysund
# Processing Record 9 of Set 10 | awjilah
# Processing Record 10 of Set 10 | rio gallegos
# Processing Record 11 of Set 10 | wabag
# Processing Record 12 of Set 10 | kununurra
# Processing Record 13 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 14 of Set 10 | acajutla
# Processing Record 15 of Set 10 | wukari
# Processing Record 16 of Set 10 | hofu
# Processing Record 17 of Set 10 | zhaotong
# Processing Record 18 of Set 10 | mingguang
# Processing Record 19 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 10 | luau
# Processing Record 21 of Set 10 | mildura
# Processing Record 22 of Set 10 | poya
# Processing Record 23 of Set 10 | fortuna
# Processing Record 24 of Set 10 | lorengau
# Processing Record 25 of Set 10 | manokwari
# Processing Record 26 of Set 10 | talara
# Processing Record 27 of Set 10 | nishihara
# Processing Record 28 of Set 10 | asyut
# Processing Record 29 of Set 10 | pangody
# Processing Record 30 of Set 10 | kangaatsiaq
# Processing Record 31 of Set 10 | garden city
# Processing Record 32 of Set 10 | marystown
# Processing Record 33 of Set 10 | marquette
# Processing Record 34 of Set 10 | yumen
# Processing Record 35 of Set 10 | chicama
# Processing Record 36 of Set 10 | thinadhoo
# Processing Record 37 of Set 10 | luangwa
# Processing Record 38 of Set 10 | ambon
# Processing Record 39 of Set 10 | santa rosalia
# Processing Record 40 of Set 10 | stornoway
# Processing Record 41 of Set 10 | tessalit
# Processing Record 42 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 43 of Set 10 | caceres
# Processing Record 44 of Set 10 | superior
# Processing Record 45 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 46 of Set 10 | ancud
# Processing Record 47 of Set 10 | ola
# Processing Record 48 of Set 10 | shache
# Processing Record 49 of Set 10 | cockburn town
# Processing Record 50 of Set 10 | san nicolas
# Processing Record 1 of Set 11 | garmsar
# Processing Record 2 of Set 11 | shubarshi
# Processing Record 3 of Set 11 | mokhsogollokh
# Processing Record 4 of Set 11 | egvekinot
# Processing Record 5 of Set 11 | pereira barreto
# Processing Record 6 of Set 11 | mawlaik
# Processing Record 7 of Set 11 | amga
# Processing Record 8 of Set 11 | pasinler
# Processing Record 9 of Set 11 | flinders
# Processing Record 10 of Set 11 | muromtsevo
# Processing Record 11 of Set 11 | anadyr
# Processing Record 12 of Set 11 | borogontsy
# Processing Record 13 of Set 11 | ilebo
# Processing Record 14 of Set 11 | erenhot
# Processing Record 15 of Set 11 | eyemouth
# Processing Record 16 of Set 11 | mayya
# Processing Record 17 of Set 11 | richards bay
# Processing Record 18 of Set 11 | lithakia
# Processing Record 19 of Set 11 | nyurba
# Processing Record 20 of Set 11 | ulefoss
# Processing Record 21 of Set 11 | north bay
# Processing Record 22 of Set 11 | namibe
# Processing Record 23 of Set 11 | zhuhai
# Processing Record 24 of Set 11 | kalanguy
# Processing Record 25 of Set 11 | raga
# Processing Record 26 of Set 11 | nadym
# Processing Record 27 of Set 11 | imbituba
# Processing Record 28 of Set 11 | anito
# Processing Record 29 of Set 11 | seymchan
# Processing Record 30 of Set 11 | walvis bay
# Processing Record 31 of Set 11 | poltavka
# Processing Record 32 of Set 11 | quatre cocos
# Processing Record 33 of Set 11 | jiangyou
# Processing Record 34 of Set 11 | oxford
# Processing Record 35 of Set 11 | inverness
# Processing Record 36 of Set 11 | kaspiyskiy
# Processing Record 37 of Set 11 | deogarh
# Processing Record 38 of Set 11 | palomares
# Processing Record 39 of Set 11 | sakaiminato
# Processing Record 40 of Set 11 | grand gaube
# Processing Record 41 of Set 11 | port-cartier
# Processing Record 42 of Set 11 | nacimiento
# Processing Record 43 of Set 11 | belle glade
# Processing Record 44 of Set 11 | yelandur
# Processing Record 45 of Set 11 | high level
# Processing Record 46 of Set 11 | newport
# Processing Record 47 of Set 11 | strezhevoy
# Processing Record 48 of Set 11 | svetlyy
# Processing Record 49 of Set 11 | katima mulilo
# Processing Record 50 of Set 11 | uberlandia
# Processing Record 1 of Set 12 | bukama
# Processing Record 2 of Set 12 | bilma
# Processing Record 3 of Set 12 | dingle
# Processing Record 4 of Set 12 | ryotsu
# Processing Record 5 of Set 12 | bereda
# Processing Record 6 of Set 12 | vila velha
# Processing Record 7 of Set 12 | severobaykalsk
# Processing Record 8 of Set 12 | makakilo city
# Processing Record 9 of Set 12 | santa cruz de la palma
# Processing Record 10 of Set 12 | gushikawa
# Processing Record 11 of Set 12 | komsomolskiy
# Processing Record 12 of Set 12 | deer lake
# Processing Record 13 of Set 12 | manali
# Processing Record 14 of Set 12 | davila
# Processing Record 15 of Set 12 | carikar
# City not found. Skipping...
# Processing Record 16 of Set 12 | nanae
# Processing Record 17 of Set 12 | oranjemund
# Processing Record 18 of Set 12 | kankan
# Processing Record 19 of Set 12 | guarapari
# Processing Record 20 of Set 12 | mahanje
# Processing Record 21 of Set 12 | pitimbu
# Processing Record 22 of Set 12 | bulungu
# Processing Record 23 of Set 12 | mayo
# Processing Record 24 of Set 12 | jati
# Processing Record 25 of Set 12 | kassala
# Processing Record 26 of Set 12 | kalmunai
# Processing Record 27 of Set 12 | yeniseysk
# Processing Record 28 of Set 12 | praia da vitoria
# Processing Record 29 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 30 of Set 12 | yulara
# Processing Record 31 of Set 12 | orkney
# Processing Record 32 of Set 12 | hvide sande
# Processing Record 33 of Set 12 | saint anthony
# Processing Record 34 of Set 12 | talaya
# Processing Record 35 of Set 12 | half moon bay
# Processing Record 36 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 37 of Set 12 | namatanai
# Processing Record 38 of Set 12 | kautokeino
# Processing Record 39 of Set 12 | presidente medici
# Processing Record 40 of Set 12 | mariinsk
# Processing Record 41 of Set 12 | jurado
# Processing Record 42 of Set 12 | new plymouth
# Processing Record 43 of Set 12 | bongandanga
# Processing Record 44 of Set 12 | saint-georges
# Processing Record 45 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 46 of Set 12 | fukue
# Processing Record 47 of Set 12 | smoky lake
# Processing Record 48 of Set 12 | kamyaran
# Processing Record 49 of Set 12 | avera
# Processing Record 50 of Set 12 | gardan diwal
# City not found. Skipping...
# Processing Record 1 of Set 13 | auki
# Processing Record 2 of Set 13 | ambunti
# Processing Record 3 of Set 13 | altay
# Processing Record 4 of Set 13 | touros
# Processing Record 5 of Set 13 | jacksonville
# Processing Record 6 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 13 | tahta
# Processing Record 8 of Set 13 | blonduos
# City not found. Skipping...
# Processing Record 9 of Set 13 | tondon
# Processing Record 10 of Set 13 | akkermanovka
# Processing Record 11 of Set 13 | ostersund
# Processing Record 12 of Set 13 | pueblo nuevo
# Processing Record 13 of Set 13 | dauphin
# Processing Record 14 of Set 13 | angoche
# Processing Record 15 of Set 13 | oktyabrskoye
# Processing Record 16 of Set 13 | chapais
# Processing Record 17 of Set 13 | siverek
# Processing Record 18 of Set 13 | romitan
# Processing Record 19 of Set 13 | inhambane
# Processing Record 20 of Set 13 | puerto ayacucho
# Processing Record 21 of Set 13 | poso
# Processing Record 22 of Set 13 | saint-junien
# Processing Record 23 of Set 13 | malindi
# Processing Record 24 of Set 13 | nanyang
# Processing Record 25 of Set 13 | naze
# Processing Record 26 of Set 13 | mounana
# Processing Record 27 of Set 13 | nanortalik
# Processing Record 28 of Set 13 | bhor
# Processing Record 29 of Set 13 | ariquemes
# Processing Record 30 of Set 13 | huanan
# Processing Record 31 of Set 13 | ranong
# Processing Record 32 of Set 13 | verkhnevilyuysk
# Processing Record 33 of Set 13 | sibolga
# Processing Record 34 of Set 13 | letka
# Processing Record 35 of Set 13 | hailar
# Processing Record 36 of Set 13 | along
# Processing Record 37 of Set 13 | hadejia
# Processing Record 38 of Set 13 | statesboro
# Processing Record 39 of Set 13 | qasigiannguit
# Processing Record 40 of Set 13 | guerrero negro
# Processing Record 41 of Set 13 | cristobal obregon
# Processing Record 42 of Set 13 | shimanovsk
# Processing Record 43 of Set 13 | buchanan
# Processing Record 44 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 45 of Set 13 | pangoa
# Processing Record 46 of Set 13 | zabol
# Processing Record 47 of Set 13 | gallup
# Processing Record 48 of Set 13 | hassleholm
# Processing Record 49 of Set 13 | koshurnikovo
# Processing Record 50 of Set 13 | faya
# Processing Record 1 of Set 14 | dubbo
# Processing Record 2 of Set 14 | alexandroupoli
# Processing Record 3 of Set 14 | guanay
# Processing Record 4 of Set 14 | les cayes
# Processing Record 5 of Set 14 | po
# City not found. Skipping...
# Processing Record 6 of Set 14 | eureka
# Processing Record 7 of Set 14 | celestun
# Processing Record 8 of Set 14 | vieste
# Processing Record 9 of Set 14 | sinnamary
# Processing Record 10 of Set 14 | nome
# Processing Record 11 of Set 14 | katobu
# Processing Record 12 of Set 14 | ilheus
# Processing Record 13 of Set 14 | talcahuano
# Processing Record 14 of Set 14 | chengde
# Processing Record 15 of Set 14 | mao
# Processing Record 16 of Set 14 | padang
# Processing Record 17 of Set 14 | christchurch
# Processing Record 18 of Set 14 | san ignacio
# Processing Record 19 of Set 14 | aswan
# Processing Record 20 of Set 14 | jinxi
# Processing Record 21 of Set 14 | dongsheng
# Processing Record 22 of Set 14 | dubti
# Processing Record 23 of Set 14 | sistranda
# Processing Record 24 of Set 14 | rosa zarate
# Processing Record 25 of Set 14 | mezen
# Processing Record 26 of Set 14 | byron bay
# Processing Record 27 of Set 14 | salacgriva
# Processing Record 28 of Set 14 | juneau
# Processing Record 29 of Set 14 | acapulco
# Processing Record 30 of Set 14 | kumluca
# Processing Record 31 of Set 14 | muros
# Processing Record 32 of Set 14 | yenagoa
# Processing Record 33 of Set 14 | javanrud
# Processing Record 34 of Set 14 | dipkarpaz
# City not found. Skipping...
# Processing Record 35 of Set 14 | tezu
# Processing Record 36 of Set 14 | nara
# Processing Record 37 of Set 14 | tsaratanana
# Processing Record 38 of Set 14 | mbaiki
# Processing Record 39 of Set 14 | tegh
# Processing Record 40 of Set 14 | lodwar
# Processing Record 41 of Set 14 | yefira
# City not found. Skipping...
# Processing Record 42 of Set 14 | lashio
# Processing Record 43 of Set 14 | demerval lobao
# Processing Record 44 of Set 14 | berlevag
# Processing Record 45 of Set 14 | tamazulapam
# City not found. Skipping...
# Processing Record 46 of Set 14 | komarov
# Processing Record 47 of Set 14 | baykit
# Processing Record 48 of Set 14 | samarai
# Processing Record 49 of Set 14 | gonbad-e qabus
# Processing Record 50 of Set 14 | sayyan
# Processing Record 1 of Set 15 | pozo colorado
# Processing Record 2 of Set 15 | chalus
# Processing Record 3 of Set 15 | praia
# Processing Record 4 of Set 15 | coruripe
# Processing Record 5 of Set 15 | arteaga
# Processing Record 6 of Set 15 | llangefni
# Processing Record 7 of Set 15 | agsu
# City not found. Skipping...
# Processing Record 8 of Set 15 | kinshasa
# Processing Record 9 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 15 | ibra
# Processing Record 11 of Set 15 | atikokan
# Processing Record 12 of Set 15 | doba
# Processing Record 13 of Set 15 | cervo
# Processing Record 14 of Set 15 | urumqi
# Processing Record 15 of Set 15 | zhangjiakou
# Processing Record 16 of Set 15 | ciudad bolivar
# Processing Record 17 of Set 15 | buala
# Processing Record 18 of Set 15 | melfi
# Processing Record 19 of Set 15 | zhanaozen
# Processing Record 20 of Set 15 | mahesana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 655

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Norman Wells      CA  65.2820 -126.8329     25.12        96          10
# 1    Coahuayana      MX  18.7333 -103.6833     78.33        88          45
# 2       Isangel      VU -19.5500  169.2667     76.42        73           8
# 3         Kapaa      US  22.0752 -159.3190     82.38        72          20
# 4       Mataura      NZ -46.1927  168.8643     66.47        40          67
# 5    Bredasdorp      ZA -34.5322   20.0403     58.28        96          39
# 6      Hermanus      ZA -34.4187   19.2345     63.90        89           1
# 7   Yellowknife      CA  62.4560 -114.3525     36.41       100         100
# 8     Belyy Yar      RU  53.6039   91.3903     40.89        70          75
# 9   Tuktoyaktuk      CA  69.4541 -133.0374     31.05        83         100
#
#    Wind Speed Current Description
# 0        3.91           clear sky
# 1        2.53    scattered clouds
# 2       14.12           clear sky
# 3        4.00          few clouds
# 4        3.22       broken clouds
# 5        8.16    scattered clouds
# 6       13.96           clear sky
# 7        9.22          light rain
# 8        2.24       broken clouds
# 9       14.85     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
